# %%
from PIL import Image
import numpy as np
import torch
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torchvision.transforms.functional import InterpolationMode

import albumentations as A
from albumentations.pytorch import ToTensorV2
import argparse
import json
import pathlib
import unittest
from typing import Tuple

# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname("."))))
import utils
args = argparse.Namespace()
args.num_clients = 10

args.dirichlet_alpha = 0.1
N_parties = args.num_clients

alpha = args.dirichlet_alpha
args.unique_patients = True

# %%
import torchxrayvision
from skmultilearn.model_selection import iterative_train_test_split
from skmultilearn.model_selection.measures import get_combination_wise_output_matrix

class Custom_RSNA_Dataset(torchxrayvision.datasets.RSNA_Pneumonia_Dataset):
    def __getitem__(self, index):
        sample = super().__getitem__(index)
        return sample['img'], sample['lab']
    
class Custom_NIH_Dataset(torchxrayvision.datasets.NIH_Dataset):
    def __getitem__(self, index):
        sample = super().__getitem__(index)
        return sample['img'], sample['lab']

class Custom_CheX_Dataset(torchxrayvision.datasets.CheX_Dataset):
    def __getitem__(self, index):
        sample = super().__getitem__(index)
        return sample['img'], sample['lab']

NIH_dataset = Custom_NIH_Dataset(imgpath="/home/suncheol/.data/NIH_224/images", views=["PA"], unique_patients=args.unique_patients)

labels = [label for _, label in NIH_dataset]
labels = np.array(labels)

indices = np.arange(len(labels)).reshape(-1, 1)
# drop no finding

no_finding_indices = np.where(labels.sum(axis=1) == 0)[0]
indices = np.delete(indices, no_finding_indices, axis=0)
labels = np.delete(labels, no_finding_indices, axis=0)

indices_train, labels_train, indices_test, labels_test = iterative_train_test_split(indices, labels, test_size=0.2)

# %%
len(indices_train), len(indices_test)
# Out:
# (22507, 5501)

# %%
splitdir = pathlib.Path("./splitfile" ) / "no_unique_patients"
splitdir.mkdir(exist_ok=True, parents=True)
NIH_dataset.csv.iloc[indices_train.flatten()].reset_index(drop=True).to_csv(splitdir / "NIH_dataset_train.csv", index=False)
NIH_dataset.csv.iloc[indices_test.flatten()].reset_index(drop=True).to_csv(splitdir / "NIH_dataset_test.csv", index=False)

# %%
train_dataset = Custom_NIH_Dataset(imgpath="/home/suncheol/.data/NIH_224/images",
                                 csvpath=splitdir / "NIH_dataset_train.csv",
                                 views=["PA"], unique_patients=args.unique_patients)
print(len(train_dataset))
# Out:
# 22507

# %%
test_dataset = Custom_NIH_Dataset(imgpath="/home/suncheol/.data/NIH_224/images",
                                    csvpath=splitdir / "NIH_dataset_test.csv",
                                    views=["PA"], unique_patients=args.unique_patients)
print(len(test_dataset))
# Out:
# 5501

# %%
public_dataset = Custom_RSNA_Dataset(imgpath="/home/suncheol/.data/rsna/stage_2_train_images",
                                    views=["PA"])

# %%
labels = np.array([label for _, label in train_dataset])

# %%
def replace_nonzero_values(matrix):
    # 행렬의 크기를 구합니다.
    rows, cols = matrix.shape
    
    # 모든 열에 대해 반복합니다.
    for col in range(cols):
        # col 번째 열에서 0이 아닌 값의 위치를 찾습니다.
        nonzero_indices = np.nonzero(matrix[:, col])[0]
        
        # 해당 위치의 값을 col로 치환합니다.
        matrix[nonzero_indices, col] = col
    
    return matrix

labels = replace_nonzero_values(labels)

# %%
def create_label_to_id_map(labels):
    label_to_id = {}
    index = 0
    for label in labels:
        label = frozenset(label)
        if label not in label_to_id:
            label_to_id[label] = index
            index += 1
    return label_to_id

def convert_id_to_label_map(label_to_id):
    return {v: k for k, v in label_to_id.items()}

def convert_labels_to_ids(labels, label_to_id):
    return [label_to_id[frozenset(label)] for label in labels]

label_to_id = create_label_to_id_map(labels)
id_to_label = convert_id_to_label_map(label_to_id)
label_ids = convert_labels_to_ids(labels, label_to_id)

# %%
args.num_classes = len(label_to_id)
y_data = label_ids
# Out:
# 399

# %%
def get_clientid_from_index(split_dirichlet_data_index_dict):
    clientid_from_index = {}
    for clientid, indices in split_dirichlet_data_index_dict.items():
        for index in indices:
            clientid_from_index[index] = clientid
    return clientid_from_index

# %%
import pandas as pd
splitfile_csv = pd.read_csv(splitdir / "NIH_dataset_train.csv", index_col=None, header=0)

alphas = [0.1, 0.5, 1.0]
for alpha in alphas:
    utils.set_random_seed(42)
    dirichlet_accmul_count = utils.get_dirichlet_distribution_count(N_class, N_parties, y_data, alpha)
    split_dirichlet_data_index_dict = utils.get_split_data_index(y_data, dirichlet_accmul_count)
    splitfile_csv[f"client_id_{alpha}"] = splitfile_csv.index.map(get_clientid_from_index(split_dirichlet_data_index_dict))
    print(splitfile_csv[f"client_id_{alpha}"].value_counts())
# Out:
# party_id: 0, num of samples: 1997
# party_id: 1, num of samples: 1039
# party_id: 2, num of samples: 1649
# party_id: 3, num of samples: 1476
# party_id: 4, num of samples: 2033
# party_id: 5, num of samples: 2531
# party_id: 6, num of samples: 2557
# party_id: 7, num of samples: 1476
# party_id: 8, num of samples: 1865
# party_id: 9, num of samples: 5884
# client_id_0.1
# 9    5884
# 6    2557
# 5    2531
# 4    2033
# 0    1997
# 8    1865
# 2    1649
# 7    1476
# 3    1476
# 1    1039
# Name: count, dtype: int64
# party_id: 0, num of samples: 2328
# party_id: 1, num of samples: 1173
# party_id: 2, num of samples: 1932
# party_id: 3, num of samples: 2544
# party_id: 4, num of samples: 4077
# party_id: 5, num of samples: 2317
# party_id: 6, num of samples: 2180
# party_id: 7, num of samples: 1942
# party_id: 8, num of samples: 2240
# party_id: 9, num of samples: 1774
# client_id_0.5
# 4    4077
# 3    2544
# 0    2328
# 5    2317
# 8    2240
# 6    2180
# 7    1942
# 2    1932
# 9    1774
# 1    1173
# Name: count, dtype: int64
# party_id: 0, num of samples: 2168
# party_id: 1, num of samples: 2294
# party_id: 2, num of samples: 2710
# party_id: 3, num of samples: 1897
# party_id: 4, num of samples: 1590
# party_id: 5, num of samples: 2003
# party_id: 6, num of samples: 2182
# party_id: 7, num of samples: 2682
# party_id: 8, num of samples: 1902
# party_id: 9, num of samples: 3079
# client_id_1.0
# 9    3079
# 2    2710
# 7    2682
# 1    2294
# 6    2182
# 0    2168
# 5    2003
# 8    1902
# 3    1897
# 4    1590
# Name: count, dtype: int64

# %%
splitfile_csv.tail(20)
# Out:
#         index       Image Index               Finding Labels  Follow-up #
# 22487  112033  00030746_000.png       Consolidation|Effusion            0  \
# 22488  112038  00030751_000.png                 Infiltration            0
# 22489  112047  00030753_007.png  Effusion|Pleural_Thickening            7
# 22490  112050  00030753_010.png         Atelectasis|Effusion           10
# 22491  112052  00030753_012.png             Atelectasis|Mass           12
# 22492  112053  00030754_000.png                 Infiltration            0
# 22493  112054  00030755_000.png                 Infiltration            0
# 22494  112055  00030756_000.png                 Infiltration            0
# 22495  112056  00030757_000.png                 Infiltration            0
# 22496  112058  00030759_000.png                Consolidation            0
# 22497  112059  00030760_000.png                Consolidation            0
# 22498  112062  00030763_000.png                 Infiltration            0
# 22499  112063  00030764_000.png                 Cardiomegaly            0
# 22500  112078  00030774_000.png                Consolidation            0
# 22501  112084  00030780_000.png                  Atelectasis            0
# 22502  112090  00030786_000.png                     Effusion            0
# 22503  112100  00030789_000.png                 Infiltration            0
# 22504  112106  00030793_000.png                  Mass|Nodule            0
# 22505  112108  00030795_000.png           Pleural_Thickening            0
# 22506  112115  00030801_001.png               Mass|Pneumonia            1
#
#        Patient ID  Patient Age Patient Gender View Position
# 22487       30746           51              F            PA  \
# 22488       30751           36              M            PA
# 22489       30753           54              F            PA
# 22490       30753           54              F            PA
# 22491       30753           54              F            PA
# 22492       30754           53              M            PA
# 22493       30755           49              F            PA
# 22494       30756           30              M            PA
# 22495       30757           54              M            PA
# 22496       30759           50              M            PA
# 22497       30760           39              F            PA
# 22498       30763           13              M            PA
# 22499       30764           35              M            PA
# 22500       30774           43              F            PA
# 22501       30780           66              M            PA
# 22502       30786           61              F            PA
# 22503       30789           51              F            PA
# 22504       30793           57              F            PA
# 22505       30795           52              F            PA
# 22506       30801           38              M            PA
#
#        OriginalImage[Width  Height]  ...        y]  view has_masks  patientid
# 22487                 2021     2021  ...  0.194311    PA     False      30746  \
# 22488                 2020     2021  ...  0.194314    PA     False      30751
# 22489                 2021     2021  ...  0.194311    PA     False      30753
# 22490                 2021     2011  ...  0.194311    PA     False      30753
# 22491                 2021     2021  ...  0.194311    PA     False      30753
# 22492                 2020     2021  ...  0.194314    PA     False      30754
# 22493                 2021     2021  ...  0.194311    PA     False      30755
# 22494                 3056     2544  ...  0.139000    PA     False      30756
# 22495                 2020     2021  ...  0.194314    PA     False      30757
# 22496                 2021     2021  ...  0.194311    PA     False      30759
# 22497                 2021     2021  ...  0.194311    PA     False      30760
# 22498                 2544     3056  ...  0.139000    PA     False      30763
# 22499                 2021     2021  ...  0.194311    PA     False      30764
# 22500                 2021     2021  ...  0.194311    PA     False      30774
# 22501                 2021     2021  ...  0.194311    PA     False      30780
# 22502                 2021     2021  ...  0.194311    PA     False      30786
# 22503                 2021     2021  ...  0.194311    PA     False      30789
# 22504                 2021     2021  ...  0.194311    PA     False      30793
# 22505                 2021     2021  ...  0.194311    PA     False      30795
# 22506                 2048     2500  ...  0.168000    PA     False      30801
#
#        age_years  sex_male  sex_female  client_id_0.1  client_id_0.5
# 22487       51.0     False        True              9              8  \
# 22488       36.0      True       False              9              8
# 22489       54.0     False        True              9              8
# 22490       54.0     False        True              9              9
# 22491       54.0     False        True              9              9
# 22492       53.0      True       False              9              8
# 22493       49.0     False        True              9              8
# 22494       30.0      True       False              9              8
# 22495       54.0      True       False              9              9
# 22496       50.0      True       False              8              9
# 22497       39.0     False        True              8              9
# 22498       13.0      True       False              9              9
# 22499       35.0      True       False              8              9
# 22500       43.0     False        True              8              9
# 22501       66.0      True       False              9              9
# 22502       61.0     False        True              9              9
# 22503       51.0     False        True              9              9
# 22504       57.0     False        True              9              9
# 22505       52.0     False        True              9              9
# 22506       38.0      True       False              4              7
#
#        client_id_1.0
# 22487              9
# 22488              9
# 22489              9
# 22490              9
# 22491              9
# 22492              9
# 22493              9
# 22494              9
# 22495              9
# 22496              9
# 22497              9
# 22498              9
# 22499              9
# 22500              9
# 22501              9
# 22502              9
# 22503              9
# 22504              9
# 22505              9
# 22506              9
#
# [20 rows x 21 columns]

# %%
[max(value) for value in split_dirichlet_data_index_dict.values()]
# Out:
# [18530, 21425, 21372, 21973, 21277, 22351, 22306, 22460, 22442, 22506]

# %%
splitfile_csv.to_csv(splitdir / "NIH_dataset_train.csv", index=False)

# %%
args.unique_patients = False
datadir = pathlib.Path("/home/suncheol/.data/")
train_dataset = Custom_CheX_Dataset(imgpath= str(datadir / "CheXpert-v1.0-small"),
                                    csvpath= str(datadir / "CheXpert-v1.0-small/train.csv"),
                                    views=["PA"], unique_patients=args.unique_patients)



labels = [label for _, label in train_dataset]
labels = np.array(labels)
# replace -1, nan to 0
labels[labels == -1] = 0
labels[np.isnan(labels)] = 0

indices = np.arange(len(labels)).reshape(-1, 1)
# drop no finding

no_finding_indices = np.where(labels.sum(axis=1) == 0)[0]
indices = np.delete(indices, no_finding_indices, axis=0)
labels = np.delete(labels, no_finding_indices, axis=0)

if args.unique_patients:
    splitdir = pathlib.Path("./splitfile" ) / "unique_patients"
else:
    splitdir = pathlib.Path("./splitfile" ) / "no_unique_patients"
splitdir.mkdir(exist_ok=True, parents=True)
indices_train, labels_train, indices_test, labels_test = iterative_train_test_split(indices, labels, test_size=0.2)
train_dataset.csv.iloc[indices_train.flatten()].reset_index(drop=True).to_csv(splitdir / "CheX_dataset_train.csv", index=False)
train_dataset.csv.iloc[indices_test.flatten()].reset_index(drop=True).to_csv(splitdir / "CheX_dataset_train_test.csv", index=False)

# %%
len(indices_train), len(indices_test)
# Out:
# (11979, 2942)

# %%
valid_dataset = Custom_CheX_Dataset(imgpath= str(datadir / "CheXpert-v1.0-small"),
                                    csvpath= str(datadir / "CheXpert-v1.0-small/valid.csv"),
                                    views=["PA"], unique_patients=args.unique_patients)

labels = [label for _, label in valid_dataset]
labels = np.array(labels)
labels[labels == -1] = 0
labels[np.isnan(labels)] = 0

print(labels.shape, labels.sum(axis=1).shape)
indices = np.arange(len(labels)).reshape(-1, 1)
# drop no finding

no_finding_indices = np.where(labels.sum(axis=1) == 0)[0]
indices = np.delete(indices, no_finding_indices, axis=0)
labels = np.delete(labels, no_finding_indices, axis=0)
print(len(indices))
valid_dataset.csv.iloc[indices.flatten()].reset_index(drop=True).to_csv(splitdir / "CheX_dataset_valid.csv", index=False)
# Out:
# (33, 13) (33,)
# 15

# %%
train_dataset = Custom_CheX_Dataset(imgpath= str(datadir / "CheXpert-v1.0-small"),
                                    csvpath= str(splitdir / "CheX_dataset_train.csv"),
                                    views=["PA"], unique_patients=args.unique_patients)
print(len(train_dataset))
# Out:
# 17859

# %%
test_dataset = Custom_CheX_Dataset(imgpath= str(datadir / "CheXpert-v1.0-small"),
                                    csvpath= str(splitdir / "CheX_dataset_train_test.csv"),
                                    views=["PA"], unique_patients=args.unique_patients)
print(len(test_dataset))
# Out:
# 2942

# %%
valid_dataset = Custom_CheX_Dataset(imgpath= str(datadir / "CheXpert-v1.0-small"),
                                    csvpath= str(splitdir / "CheX_dataset_valid.csv"),
                                    views=["PA"], unique_patients=args.unique_patients)
print(len(valid_dataset))
# Out:
# 15

# %%
public_dataset = Custom_RSNA_Dataset(imgpath="/home/suncheol/.data/rsna/stage_2_train_images",
                                    views=["PA"])

# %%
labels = np.array([label for _, label in train_dataset])
labels = np.array(labels)
labels[labels == -1] = 0
labels[np.isnan(labels)] = 0

# %%
def replace_nonzero_values(matrix):
    # 행렬의 크기를 구합니다.
    rows, cols = matrix.shape
    
    # 모든 열에 대해 반복합니다.
    for col in range(cols):
        # col 번째 열에서 0이 아닌 값의 위치를 찾습니다.
        nonzero_indices = np.nonzero(matrix[:, col])[0]
        
        # 해당 위치의 값을 col로 치환합니다.
        matrix[nonzero_indices, col] = col
    
    return matrix

labels = replace_nonzero_values(labels)

# %%
def create_label_to_id_map(labels):
    label_to_id = {}
    index = 0
    for label in labels:
        label = frozenset(label)
        if label not in label_to_id:
            label_to_id[label] = index
            index += 1
    return label_to_id

def convert_id_to_label_map(label_to_id):
    return {v: k for k, v in label_to_id.items()}

def convert_labels_to_ids(labels, label_to_id):
    return [label_to_id[frozenset(label)] for label in labels]

label_to_id = create_label_to_id_map(labels)
id_to_label = convert_id_to_label_map(label_to_id)
label_ids = convert_labels_to_ids(labels, label_to_id)

# %%
args.num_classes = len(label_to_id)
y_data = label_ids
N_class = args.num_classes
print(N_class)
# Out:
# 508

# %%
def get_clientid_from_index(split_dirichlet_data_index_dict):
    clientid_from_index = {}
    for clientid, indices in split_dirichlet_data_index_dict.items():
        for index in indices:
            clientid_from_index[index] = clientid
    return clientid_from_index

# %%
import pandas as pd
splitfile_csv = pd.read_csv(splitdir / "CheX_dataset_train.csv", index_col=None, header=0)

alphas = [0.1, 0.5, 1.0]
for alpha in alphas:
    utils.set_random_seed(42)
    dirichlet_accmul_count = utils.get_dirichlet_distribution_count(N_class, N_parties, y_data, alpha)
    split_dirichlet_data_index_dict = utils.get_split_data_index(y_data, dirichlet_accmul_count)
    splitfile_csv[f"client_id_{alpha}"] = splitfile_csv.index.map(get_clientid_from_index(split_dirichlet_data_index_dict))
    print(splitfile_csv[f"client_id_{alpha}"].value_counts())
# Out:
# party_id: 0, num of samples: 2051
# party_id: 1, num of samples: 550
# party_id: 2, num of samples: 1261
# party_id: 3, num of samples: 1158
# party_id: 4, num of samples: 1603
# party_id: 5, num of samples: 3336
# party_id: 6, num of samples: 2253
# party_id: 7, num of samples: 1241
# party_id: 8, num of samples: 2531
# party_id: 9, num of samples: 1875
# client_id_0.1
# 5    3336
# 8    2531
# 6    2253
# 0    2051
# 9    1875
# 4    1603
# 2    1261
# 7    1241
# 3    1158
# 1     550
# Name: count, dtype: int64
# party_id: 0, num of samples: 2210
# party_id: 1, num of samples: 1468
# party_id: 2, num of samples: 1483
# party_id: 3, num of samples: 1585
# party_id: 4, num of samples: 2805
# party_id: 5, num of samples: 2293
# party_id: 6, num of samples: 2079
# party_id: 7, num of samples: 1335
# party_id: 8, num of samples: 1144
# party_id: 9, num of samples: 1457
# client_id_0.5
# 4    2805
# 5    2293
# 0    2210
# 6    2079
# 3    1585
# 2    1483
# 1    1468
# 9    1457
# 7    1335
# 8    1144
# Name: count, dtype: int64
# party_id: 0, num of samples: 1958
# party_id: 1, num of samples: 2266
# party_id: 2, num of samples: 1412
# party_id: 3, num of samples: 1906
# party_id: 4, num of samples: 1712
# party_id: 5, num of samples: 2177
# party_id: 6, num of samples: 1646
# party_id: 7, num of samples: 1906
# party_id: 8, num of samples: 1718
# party_id: 9, num of samples: 1158
# client_id_1.0
# 1    2266
# 5    2177
# 0    1958
# 7    1906
# 3    1906
# 8    1718
# 4    1712
# 6    1646
# 2    1412
# 9    1158
# Name: count, dtype: int64

# %%
splitfile_csv.tail(20)
# Out:
#                                                     Path     Sex  Age
# 17839  CheXpert-v1.0-small/train/patient34573/study3/...    Male   72  \
# 17840  CheXpert-v1.0-small/train/patient34573/study1/...    Male   71
# 17841  CheXpert-v1.0-small/train/patient34573/study2/...    Male   72
# 17842  CheXpert-v1.0-small/train/patient34574/study5/...    Male   81
# 17843  CheXpert-v1.0-small/train/patient34576/study1/...    Male   38
# 17844  CheXpert-v1.0-small/train/patient34579/study1/...    Male   87
# 17845  CheXpert-v1.0-small/train/patient34583/study2/...    Male   39
# 17846  CheXpert-v1.0-small/train/patient34584/study6/...  Female   59
# 17847  CheXpert-v1.0-small/train/patient34584/study5/...  Female   58
# 17848  CheXpert-v1.0-small/train/patient34587/study1/...    Male   73
# 17849  CheXpert-v1.0-small/train/patient34591/study2/...    Male   21
# 17850  CheXpert-v1.0-small/train/patient34593/study1/...    Male   45
# 17851  CheXpert-v1.0-small/train/patient35391/study1/...  Female   61
# 17852  CheXpert-v1.0-small/train/patient36755/study1/...    Male   81
# 17853  CheXpert-v1.0-small/train/patient39693/study1/...  Female   43
# 17854  CheXpert-v1.0-small/train/patient40779/study2/...    Male   45
# 17855  CheXpert-v1.0-small/train/patient41739/study1/...  Female   62
# 17856  CheXpert-v1.0-small/train/patient44899/study3/...  Female   90
# 17857  CheXpert-v1.0-small/train/patient51052/study1/...    Male   58
# 17858  CheXpert-v1.0-small/train/patient52592/study2/...  Female   32
#
#       Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum
# 17839         Frontal    PA         NaN                         NaN  \
# 17840         Frontal    PA         NaN                         NaN
# 17841         Frontal    PA         NaN                         0.0
# 17842         Frontal    PA         NaN                        -1.0
# 17843         Frontal    PA         NaN                         NaN
# 17844         Frontal    PA         NaN                         NaN
# 17845         Frontal    PA         NaN                         1.0
# 17846         Frontal    PA         NaN                         NaN
# 17847         Frontal    PA         NaN                         NaN
# 17848         Frontal    PA         NaN                        -1.0
# 17849         Frontal    PA         NaN                         NaN
# 17850         Frontal    PA         NaN                         1.0
# 17851         Frontal    PA         NaN                         NaN
# 17852         Frontal    PA         NaN                         NaN
# 17853         Frontal    PA         NaN                         NaN
# 17854         Frontal    PA         NaN                         NaN
# 17855         Frontal    PA         NaN                         NaN
# 17856         Frontal    PA         NaN                         NaN
# 17857         Frontal    PA         NaN                         NaN
# 17858         Frontal    PA         NaN                         NaN
#
#        Cardiomegaly  Lung Opacity  Lung Lesion  ...  Fracture
# 17839           NaN           1.0          1.0  ...       NaN  \
# 17840           0.0           1.0          NaN  ...       NaN
# 17841           NaN           NaN          1.0  ...       NaN
# 17842           1.0           NaN          NaN  ...       NaN
# 17843           NaN           1.0          NaN  ...       NaN
# 17844           NaN           NaN          NaN  ...       1.0
# 17845           NaN           NaN          NaN  ...       NaN
# 17846           NaN           NaN          NaN  ...       NaN
# 17847           NaN           1.0          NaN  ...       NaN
# 17848           NaN           NaN          NaN  ...       NaN
# 17849           NaN           NaN          NaN  ...       NaN
# 17850           1.0           1.0          NaN  ...       NaN
# 17851           NaN           NaN          NaN  ...       NaN
# 17852           NaN           NaN          NaN  ...       NaN
# 17853           NaN           1.0          NaN  ...       NaN
# 17854           NaN           1.0          NaN  ...       NaN
# 17855           1.0           NaN          NaN  ...       NaN
# 17856           1.0           1.0          NaN  ...       NaN
# 17857           NaN           1.0          NaN  ...       NaN
# 17858           1.0           NaN          NaN  ...       NaN
#
#        Support Devices  view  patientid  age_years  sex_male  sex_female
# 17839              NaN    PA      34573       72.0      True       False  \
# 17840              NaN    PA      34573       71.0      True       False
# 17841              NaN    PA      34573       72.0      True       False
# 17842              NaN    PA      34574       81.0      True       False
# 17843              NaN    PA      34576       38.0      True       False
# 17844              1.0    PA      34579       87.0      True       False
# 17845              NaN    PA      34583       39.0      True       False
# 17846              NaN    PA      34584       59.0     False        True
# 17847              NaN    PA      34584       58.0     False        True
# 17848              1.0    PA      34587       73.0      True       False
# 17849              NaN    PA      34591       21.0      True       False
# 17850              1.0    PA      34593       45.0      True       False
# 17851              1.0    PA      35391       61.0     False        True
# 17852              NaN    PA      36755       81.0      True       False
# 17853              1.0    PA      39693       43.0     False        True
# 17854              NaN    PA      40779       45.0      True       False
# 17855              1.0    PA      41739       62.0     False        True
# 17856              NaN    PA      44899       90.0     False        True
# 17857              NaN    PA      51052       58.0      True       False
# 17858              1.0    PA      52592       32.0     False        True
#
#        client_id_0.1  client_id_0.5 client_id_1.0
# 17839              9              8             8
# 17840              9              9             9
# 17841              8              9             9
# 17842              6              9             9
# 17843              8              9             9
# 17844              7              9             9
# 17845              9              8             9
# 17846              8              9             9
# 17847              8              9             9
# 17848              8              8             9
# 17849              8              9             9
# 17850              8              9             9
# 17851              9              9             9
# 17852              7              9             9
# 17853              9              8             9
# 17854              6              9             9
# 17855              8              8             9
# 17856              7              9             9
# 17857              9              2             4
# 17858              6              9             9
#
# [20 rows x 27 columns]

# %%
[max(value) for value in split_dirichlet_data_index_dict.values()]
# Out:
# [12807, 16096, 17837, 17526, 17857, 17742, 17654, 17773, 17839, 17858]

# %%
splitfile_csv.to_csv(splitdir / "CheX_dataset_train.csv", index=False)

# %%
# # files in /home/suncheol/code/FedTest/0_FedMHAD_vit/_prepare_dataset/splitfile/no_unique_patients

# path = pathlib.Path("/home/suncheol/code/FedTest/0_FedMHAD_vit/_prepare_dataset/splitfile/unique_patients")

# for filename in path.glob("*.csv"):
#     # replace -1, nan to 0
#     if "CheX" in filename.name:
#         splitfile_csv = pd.read_csv(filename, index_col=None, header=0)
#         splitfile_csv.fillna(0, inplace=True)
#         splitfile_csv.replace(-1, 0, inplace=True)
#         splitfile_csv.to_csv(filename, index=False)
